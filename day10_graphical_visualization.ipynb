# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %% [raw]
# 1.Matplotlib
# 2.Pandas
# 3.Seaborn
# 4.Plotly

# %% [markdown]
# Matplotlib

# %% [raw]
# 1 plot -> Line Plot
# 2 box -> Box Plot, that is statstical view of your data in terms of boxes; mean, max,min, 50%, 25%, 75%, outlier
# 3 boxplot -> Box Plot, that is statstical view of your data in terms of boxes; mean, max,min, 50%, 25%, 75%, outlier
# 4 bar -> shows the data in terms of bars (Vertical)
# 5 barh -> Horizontal Bar Graph
# 6 hist -> Frequency of Data in Bars
# 7 hexbin -> Scatter plot, but shape of points in hexagon
# 8 pie -> Pie Chart
# 9 scatter -> Ordinary Scatter plot (compares two different numerical Data)
# 10 stem -> skeleton version of bar graph
# 11 step -> Step Graph
# 12 violinplot -> Violin version of Boxplot

# %%
a = np.arange(40)
b = np.random.randn(40,1)

# %%
plt.plot(a,b)

# %%
plt.plot(a)

# %%
plt.plot(b)
#plt.show()

# %%
s=plt.figure(figsize=(14,8))
s=plt.plot(a,b)
s=plt.grid()
s=plt.title('Data Graph')
s=plt.xlabel('X Axis --->')
s=plt.ylabel('Y Axis --->')
s=plt.legend('Random Line')
s= plt.xticks(range(0,41,10),['Zero', 'Ten','Twenty','Thirty','Forty'])

# %%
s = plt.figure(figsize=(16,10))
s = plt.plot(a,b, color='b', marker = 'o', markerfacecolor='r',markeredgecolor='blue',lw=5,ls='-.',markersize=8)
s = plt.grid()
s = plt.title('Data Graph')
s = plt.xlabel('X Axis-->')
s = plt.ylabel('Y Axis-->')
s = plt.legend('Random Line')
s = plt.xticks(range(0,41,10),['Zero', 'Ten','Twenty','Thirty','Forty'])

# %%
df1 = pd.read_csv('file.txt')
df2 = pd.read_csv('file2.txt')
df3 = pd.read_csv('file3.txt')
df1.head()
# Out:
#    Unnamed: 0         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.shape
# Out:
# (499, 4)

# %%
s = plt.figure(figsize=(16,10))
s = plt.plot(df3['a'][:45], color='y', marker = 'o', markerfacecolor='r',markeredgecolor='blue',lw=5,ls='-.',markersize=8)
s = plt.plot(df3['b'][:45], color='g', marker = '*', markerfacecolor='r',markeredgecolor='blue',lw=5,ls='-.',markersize=8)
s = plt.grid()
s = plt.title('Data Graph')
s = plt.xlabel('X Axis-->')
s = plt.ylabel('Y Axis-->')
s = plt.legend(['Random A', 'Data B'])

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
s = plt.plot(df3['a'][:30], color='b', marker = '*', markerfacecolor='r',markeredgecolor='blue',lw=3,ls='-.',markersize=10)
s = plt.grid()
s = plt.title('Random Data Graph')
s = plt.xlabel('X Data-->')
s = plt.ylabel('Y Data-->')
s = plt.legend(['Random A', 'Data B'])
plt.subplot(1,2,2)
s = plt.plot(df3['c'][:30], color='r', marker = 'o', markerfacecolor='g',markeredgecolor='blue',lw=3,ls='-.',markersize=10)
s = plt.grid()
s = plt.title('Random Data Graph')
s = plt.xlabel('X Data-->')
s = plt.ylabel('Y Data-->')
s = plt.legend(['Random A', 'Data B'])
plt.savefig('MyGraph.png',dpi=300)

# %%
# Picture In Picture
fig = plt.figure(figsize=(10,6))
ax1 = fig.add_axes([0,0,1,1]) # x,y,w,h
ax1.plot(a,b)
plt.ylim([-3, 5])
plt.xlim([0,100])
plt.grid()
plt.title('First Graph')
ax2 = fig.add_axes([0.5,0.55,0.4,0.4]) # x,y,w,h
ax2.hist(df['a'],color='r')
plt.title('Second Graph')
# Out:
# Text(0.5, 1.0, 'Second Graph')

# %%
plt.boxplot(df3['a'])# Ignore
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2406b1f4ca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2406b20c070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2406b1f4e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x2406b20c9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2406c2c9cd0>],
#  'means': []}

# %%
a.shape
# Out:
# (40,)

# %%
b.shape
# Out:
# (40, 1)

# %%
plt.bar(a,b[:,0])
# Out:
# <BarContainer object of 40 artists>

# %%
plt.barh(a,b[:,0])
# Out:
# <BarContainer object of 40 artists>

# %%
df= pd.DataFrame({'a':[34,56,78,4454,567,7,88,86,87,44,23,79]})

# %%
s=plt.hist(df['a'],bins=20)

# %%
plt.figure(figsize=(12,12))
plt.hexbin(df3['a'][:10],df3['b'][:10]) # Ignore

# %%
df4= pd.DataFrame({'a':[10,20,30,40],'b':[34,44,54,64]})

# %%
df4
# Out:
#     a   b
# 0  10  34
# 1  20  44
# 2  30  54
# 3  40  64

# %%
plt.figure(figsize=(12,12))
plt.hexbin(df4['a'],df4['b'])

# %%
plt.bar(df3['a'],df3['b'])
# Out:
# <BarContainer object of 499 artists>

# %%
plt.figure(figsize=(10,10))
plt.scatter(df4['a'],df4['b'])

# %%
df4['b']
# Out:
# 0    34
# 1    44
# 2    54
# 3    64
# Name: b, dtype: int64

# %%
s = plt.pie(df4['b'])

# %%
s= plt.pie(df4['b'], autopct="Coverage:%d%%", labels=df4['b'].index)

# %%
plt.stem(b)
# Out:
# <StemContainer object of 3 artists>

# %%
plt.violinplot(df3['a'])# Ignore
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x2406ee87ac0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x2406ee878e0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2406ee87940>,
#  'cbars': <matplotlib.collections.LineCollection at 0x2406ee99310>}

# %%
img = plt.imread('MyGraph.png')

# %%
plt.figure(figsize=(10,6))
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])

# %% [markdown]
# Pandas Functions for Graphical Visualization

# %% [raw]
# 1 plot
# 2 bar
# 3 barh
# 4 hist
# 5 box
# 6 kde
# 7 area
# 8 scatter
# 9 hexbin
# 10 pie

# %%
df3['a'].plot(color='g')
plt.grid()

# %%
df3['a'].plot.kde() # Kernel Density Estimator
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[:30].plot.hexbin(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>
